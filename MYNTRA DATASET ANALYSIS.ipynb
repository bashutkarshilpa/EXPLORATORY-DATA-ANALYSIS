# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Myntra Fasion Clothing.csv')

# %%
df
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
df.isnull().sum()
# Out:
# URL                           0
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             74306
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# URL                       0.000000
# Product_id                0.000000
# BrandName                 0.000000
# Category                  0.000000
# Individual_category       0.000000
# category_by_Gender        0.000000
# Description               0.000000
# DiscountPrice (in Rs)    36.682720
# OriginalPrice (in Rs)     0.000000
# DiscountOffer            14.111485
# SizeOption                0.000000
# Ratings                  63.838774
# Reviews                  63.838774
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526564 entries, 0 to 526563
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   URL                    526564 non-null  object
#  1   Product_id             526564 non-null  int64
#  2   BrandName              526564 non-null  object
#  3   Category               526564 non-null  object
#  4   Individual_category    526564 non-null  object
#  5   category_by_Gender     526564 non-null  object
#  6   Description            526564 non-null  object
#  7   DiscountPrice (in Rs)  333406 non-null  float64
#  8   OriginalPrice (in Rs)  526564 non-null  float64
#  9   DiscountOffer          452258 non-null  object
#  10  SizeOption             526564 non-null  object
#  11  Ratings                190412 non-null  float64
#  12  Reviews                190412 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.2+ MB

# %%
df['DiscountPrice (in Rs)']=df['DiscountPrice (in Rs)'].fillna(0)

# %%
df.isnull().sum()/len(df)*100
# Out:
# URL                       0.000000
# Product_id                0.000000
# BrandName                 0.000000
# Category                  0.000000
# Individual_category       0.000000
# category_by_Gender        0.000000
# Description               0.000000
# DiscountPrice (in Rs)     0.000000
# OriginalPrice (in Rs)     0.000000
# DiscountOffer            14.111485
# SizeOption                0.000000
# Ratings                  63.838774
# Reviews                  63.838774
# dtype: float64

# %%
df['DiscountOffer']=df['DiscountOffer'].fillna('No Offer')

# %%
sns.boxplot(df['Ratings'])
# Out:
# <AxesSubplot:xlabel='Ratings'>

# %%
df['Ratings']=df['Ratings'].fillna(df['Ratings'].mean())

# %%
df['Reviews']=df['Reviews'].fillna(0)

# %%
df.isnull().sum()/len(df)*100
# Out:
# URL                      0.0
# Product_id               0.0
# BrandName                0.0
# Category                 0.0
# Individual_category      0.0
# category_by_Gender       0.0
# Description              0.0
# DiscountPrice (in Rs)    0.0
# OriginalPrice (in Rs)    0.0
# DiscountOffer            0.0
# SizeOption               0.0
# Ratings                  0.0
# Reviews                  0.0
# dtype: float64

# %%
df.drop(['URL','Description'],axis=1,inplace=True)

# %%
df
# Out:
#         Product_id    BrandName               Category Individual_category  \
# 0          2296012     Roadster            Bottom Wear               jeans
# 1         13780156   LOCOMOTIVE            Bottom Wear         track-pants
# 2         11895958     Roadster                Topwear              shirts
# 3          4335679       Zivame  Lingerie & Sleep Wear           shapewear
# 4         11690882     Roadster                Western             tshirts
# ...            ...          ...                    ...                 ...
# 526559    16929990          H&M                Western            sweaters
# 526560    16026012          H&M                Western             jackets
# 526561    17654114  250 DESIGNS                Western             dresses
# 526562    12508700       Masaba                Western             dresses
# 526563    17856544       Jockey                Western             tshirts
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526564 entries, 0 to 526563
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Product_id             526564 non-null  int64
#  1   BrandName              526564 non-null  object
#  2   Category               526564 non-null  object
#  3   Individual_category    526564 non-null  object
#  4   category_by_Gender     526564 non-null  object
#  5   DiscountPrice (in Rs)  526564 non-null  float64
#  6   OriginalPrice (in Rs)  526564 non-null  float64
#  7   DiscountOffer          526564 non-null  object
#  8   SizeOption             526564 non-null  object
#  9   Ratings                526564 non-null  float64
#  10  Reviews                526564 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 44.2+ MB

# %%
df['Ratings'].mean()
# Out:
# 4.094892128626051

# %% [markdown]
# ### Avg rating of products in Myntra is 4.09

# %%
df['OriginalPrice (in Rs)'].max()
# Out:
# 90000.0

# %%
df[df['OriginalPrice (in Rs)']==df['OriginalPrice (in Rs)'].max()]
# Out:
#         Product_id BrandName     Category Individual_category  \
# 402189    16872366    Masaba  Indian Wear       lehenga-choli
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# 402189              Women                    0.0                90000.0
#
#        DiscountOffer       SizeOption   Ratings  Reviews
# 402189      No Offer  XS, S, M, L, XL  4.094892      0.0

# %% [markdown]
# #### The Product which costliest one sold in Myntra is Masaba Brand Lehenga choli whose cost is 90,000 and have rating of about 4.09

# %% [markdown]
# ### The highest discount given by the company

# %%
df['DiscountPrice (in Rs)'].max()
# Out:
# 27996.0

# %%
df[df['DiscountPrice (in Rs)']==df['DiscountPrice (in Rs)'].max()]
# Out:
#         Product_id BrandName     Category Individual_category  \
# 253806    17156920     Woods  Sports Wear             jackets
# 292315    16490958     Woods      Topwear             jackets
# 292316    16490994     Woods      Topwear             jackets
# 292317    16491000     Woods      Topwear             jackets
# 292318    16829124  Woodland      Topwear             jackets
# 292319    16830482     Woods      Topwear             jackets
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# 253806                Men                27996.0                34995.0
# 292315                Men                27996.0                34995.0
# 292316                Men                27996.0                34995.0
# 292317                Men                27996.0                34995.0
# 292318                Men                27996.0                34995.0
# 292319                Men                27996.0                34995.0
#
# ...

# %% [markdown]
# ### All the above products got discount price of 27996

# %%
df['DiscountOffer'].max()
# Out:
# 'Rs. 999 OFF'

# %%
df[df['DiscountOffer']==df['DiscountOffer'].max()]
# Out:
#         Product_id                 BrandName               Category  \
# 61262     14714748                   Harvard                Western
# 100137    14714776                   Harvard                Western
# 184255    14351850                Bene Kleed  Lingerie & Sleep Wear
# 324550    18364928           GULMOHAR JAIPUR            Indian Wear
# 324551    18364914           GULMOHAR JAIPUR            Indian Wear
# 324868    18364948           GULMOHAR JAIPUR            Indian Wear
# 325610    18364930           GULMOHAR JAIPUR            Indian Wear
# 325782    18364910           GULMOHAR JAIPUR            Indian Wear
# 337657    17829620                    Molcha            Indian Wear
# 337857    17829618                    Molcha            Indian Wear
# 337911    17829622                    Molcha            Indian Wear
# 413328    17021094                FLAMBOYANT  Lingerie & Sleep Wear
# 413329    17021102                FLAMBOYANT  Lingerie & Sleep Wear
# ...

# %% [markdown]
# ### MAX DISCOUNT OF 999Rs Given by Myntra for products above

# %% [markdown]
# ### Products from range 1000-5000

# %%
pr_1k_5k=df[(df['OriginalPrice (in Rs)']>999)&(df['OriginalPrice (in Rs)']<=5000)]

# %%
pr_1k=df[(df['OriginalPrice (in Rs)']<=1000)]

# %%
pr_5k_10k=df[(df['OriginalPrice (in Rs)']<=10000)&(df['OriginalPrice (in Rs)']>5000)]

# %%
pr_10k_above=df[(df['OriginalPrice (in Rs)']>10000)]

# %%
len(pr_1k_5k)
# Out:
# 402281

# %%
pr_1k_5k
# Out:
#         Product_id           BrandName               Category  \
# 0          2296012            Roadster            Bottom Wear
# 1         13780156          LOCOMOTIVE            Bottom Wear
# 2         11895958            Roadster                Topwear
# 3          4335679              Zivame  Lingerie & Sleep Wear
# 6          6744434          HIGHLANDER            Bottom Wear
# ...            ...                 ...                    ...
# 522456    14212206  The Kaftan Company                Western
# 522457    14212200  The Kaftan Company                Western
# 522458    17863418         Forever New                Western
# 522459    18153042         Forever New                Western
# 522460    17863398         Forever New                Western
#
#        Individual_category category_by_Gender  DiscountPrice (in Rs)  \
# 0                    jeans                Men                  824.0
# 1              track-pants                Men                  517.0
# ...

# %%
len(pr_1k)
# Out:
# 89328

# %%
pr_1k
# Out:
#         Product_id            BrandName Category Individual_category  \
# 4         11690882             Roadster  Western             tshirts
# 5          2490950       Mast & Harbour  Western                tops
# 11        10307375             Roadster  Topwear             tshirts
# 14         2312181             Roadster  Western             tshirts
# 19         2522986           DressBerry  Western             tshirts
# ...            ...                  ...      ...                 ...
# 526513     2196380       Style Quotient  Western                tops
# 526514     2066598  Honey by Pantaloons  Western             tshirts
# 526515     1222899    Park Avenue Woman  Western             tshirts
# 526516    18274818               UNMADE  Western                tops
# 526563    17856544               Jockey  Western             tshirts
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# ...

# %%
len(pr_5k_10k)
# Out:
# 31404

# %%
pr_5k_10k
# Out:
#         Product_id    BrandName     Category Individual_category  \
# 353       12631330       Inddus  Indian Wear              sarees
# 378       12048344       Inddus  Indian Wear              sarees
# 431       14046728      Varanga  Indian Wear          kurta-sets
# 607       10968928       Mitera  Indian Wear              sarees
# 657       13817718        Ishin  Indian Wear          kurta-sets
# ...            ...          ...          ...                 ...
# 526558    14169368       Masaba      Western             dresses
# 526559    16929990          H&M      Western            sweaters
# 526560    16026012          H&M      Western             jackets
# 526561    17654114  250 DESIGNS      Western             dresses
# 526562    12508700       Masaba      Western             dresses
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# 353                 Women                 2479.0                 6199.0
# ...

# %%
len(pr_10k_above)
# Out:
# 3765

# %%
pr_10k_above
# Out:
#         Product_id             BrandName     Category Individual_category  \
# 9590      15126604           Amrutam Fab  Indian Wear       lehenga-choli
# 17847     11383970                Shaily  Indian Wear       lehenga-choli
# 19184     13161544             Justanned      Topwear             jackets
# 23926     14834818               Mameraa  Indian Wear       lehenga-choli
# 26344     13066946                 KISAH  Indian Wear            sherwani
# ...            ...                   ...          ...                 ...
# 516425    14255856  FORCLAZ By Decathlon      Western             jackets
# 517841    16824816                Masaba      Western             dresses
# 519757    15222650                Masaba      Western             dresses
# 520015    17976124                  DKNY      Western             dresses
# 520551    16306258                  GANT      Western             blazers
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# ...

# %%
list1=['BELOW 1K','1K-5K','5K-10K','ABOVE 10K']
list2=[len(pr_1k),len(pr_1k_5k),len(pr_5k_10k),len(pr_10k_above)]

# %%
df_price_range=pd.DataFrame({'PRICE RANGE':list1,'NO.OF PRODUCTS':list2})

# %%
df_price_range
# Out:
#   PRICE RANGE  NO.OF PRODUCTS
# 0    BELOW 1K           89328
# 1       1K-5K          402281
# 2      5K-10K           31404
# 3   ABOVE 10K            3765

# %%
sns.barplot(x=df_price_range['PRICE RANGE'],y=df_price_range['NO.OF PRODUCTS'])
# Out:
# <AxesSubplot:xlabel='PRICE RANGE', ylabel='NO.OF PRODUCTS'>

# %%
plt.pie(df_price_range['NO.OF PRODUCTS'], labels=list1, colors=['skyblue','pink','blue','red'], autopct='%.0f%%')
plt.show()

# %% [markdown]
# #### 76% PRODUCTS----->In Range 1K-5K
# #### 17% PRODUCTS-----> In Range below 1K
# #### 6% PRODUCTS------->In Range 5K-10K
# #### 1% PRODUCTS------->In Range above 10k

# %% [markdown]
# #### MOST POPULAR BRAND THAT SOLD HIGHEST

# %%
df[df['BrandName']==df['BrandName'].mode().iloc[0]]
# Out:
#         Product_id BrandName     Category Individual_category  \
# 55611     16945600    Pothys  Indian Wear              sarees
# 90814     17466484    Pothys  Indian Wear              sarees
# 122393    17466476    Pothys  Indian Wear              sarees
# 133748    16945608    Pothys  Indian Wear              sarees
# 133985    16945622    Pothys  Indian Wear              sarees
# ...            ...       ...          ...                 ...
# 402650    16973016    Pothys  Indian Wear              sarees
# 402651    16919474    Pothys  Indian Wear              sarees
# 402652    16919140    Pothys  Indian Wear              sarees
# 402690    15663178    Pothys  Indian Wear              sarees
# 402691    16964006    Pothys  Indian Wear              sarees
#
#        category_by_Gender  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# 55611               Women                 1030.0                 2060.0
# 90814               Women                 1030.0                 2060.0
# ...

# %% [markdown]
# #### INDIAN WEAR IS THE HIGHEST SOLD BRAND ON MYNTRA

# %% [markdown]
# ## TOP 30  Brands that Genearted Highest Revenue in Myntra

# %%
TOP_30=df.groupby('BrandName')[['OriginalPrice (in Rs)']].sum().sort_values(by='OriginalPrice (in Rs)',ascending=False).head(30)

# %%
TOP_30
# Out:
#                        OriginalPrice (in Rs)
# BrandName
# Pothys                           43282817.00
# Mitera                           27935984.69
# KALINI                           24895287.00
# SOJANYA                          17934514.00
# Roadster                         17502379.00
# Ethnic basket                    17090927.00
# DEYANN                           16156600.00
# Puma                             13863246.00
# HERE&NOW                         13238483.00
# Sangria                          11192657.00
# Anouk                            10669770.00
# HRX by Hrithik Roshan            10651133.00
# Unnati Silks                     10592611.00
# JC Collection                    10417648.00
# MANGO                            10274364.00
# KISAH                             8662103.00
# Mast & Harbour                    8566704.20
# DressBerry                        7434207.00
# SAADHVI                           6991999.00
# Florence                          6944336.00
# ...

# %%
TOP_30.plot(kind='bar',color='pink')
# Out:
# <AxesSubplot:xlabel='BrandName'>

# %% [markdown]
# #### Above are TOP 30 BRANDS that Generating highest revenue in MYNTRA

# %% [markdown]
# ## Top 30 Brand which got highest rating

# %%
Rating_30=df.groupby('BrandName')[['Ratings']].mean().sort_values(by='Ratings',ascending=False).head(30)

# %%
Rating_30
# Out:
#                                 Ratings
# BrandName
# Forca by Lifestyle             4.700000
# Newfeel By Decathlon           4.700000
# Sztori Superman                4.650000
# Zelocity                       4.600000
# Dennis Morton                  4.600000
# IVOC Plus                      4.566099
# Minions by Dressberry          4.550000
# Ratan Creation                 4.547446
# Sztori Disney                  4.509091
# PLATINUM Studio                4.500000
# Powerpuff Girls by Dressberry  4.500000
# Sztori DC                      4.500000
# AVI Living                     4.464964
# Chemistry Edition              4.450000
# Campus                         4.447446
# I like me                      4.426516
# Sztori Marvel                  4.410544
# Tom & Jerry By Sztori          4.378978
# WATKO By Decathlon             4.373723
# EXTRA LOVE BY LIBAS            4.370769
# SHERRY                         4.369489
# Trident                        4.369064
# ...

# %%
Rating_30.plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:xlabel='BrandName'>

# %% [markdown]
# ## CATEGORY WISE most Trending in myntra with highest rating

# %%
CAT_30=df.groupby('Category')[['Ratings']].mean().sort_values(by='Ratings',ascending=False).head(30)

# %%
CAT_30.plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# #### SPORTS WEAR is leading with good rating

# %% [markdown]
# ## CATEGORY WISE most revenue generating product in myntra

# %%
CAT_REV_30=df.groupby('Category')[['OriginalPrice (in Rs)']].mean().sort_values(by='OriginalPrice (in Rs)',ascending=False).head(30)

# %%
CAT_REV_30.plot(kind='bar',color='blue')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# #### INDIAN WEAR is one generates Highest revenue which has costliest products
