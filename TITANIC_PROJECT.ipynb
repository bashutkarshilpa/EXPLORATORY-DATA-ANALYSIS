# %% [markdown]
# #  IMPORTING LIBRARIES:

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # CREATING DATA FRAME FROM CSV:

# %%
titanic_df=pd.read_csv('titanic_kaggle.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # GETTING INFO:

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - Age,Cabin,Embarked columns have missing data

# %% [markdown]
# # STATISTICAL DATA OF COLUMNS:

# %%
titanic_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # No.of passengers and % of passengers in each class:

# %%
titanic_df['Pclass'].unique()    ## No.of Classes
# Out:
# array([3, 1, 2], dtype=int64)

# %%
plot=sns.countplot(x='Pclass',data=titanic_df)

# %%
plot
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
plot=sns.countplot(x='Pclass',data=titanic_df)
plot.patches
# Out:
# <Axes.ArtistList of 3 patches>

# %%
plot.patches
# Out:
# <Axes.ArtistList of 3 patches>

# %%
for patch in plot.patches:
    print(patch)       ## Ht of each column is the count of passengers in each class
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=216, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=184, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=491, angle=0)

# %% [markdown]
# ## Annotating:

# %%
plot=sns.countplot(x='Pclass',data=titanic_df)
for patch in plot.patches:
    count=patch.get_height()
    x=patch.get_x()+0.4
    y=count/2
    plot.annotate(count,(x,y))

# %% [markdown]
# ### Conclusion:
# - No.of passengers in Pclass-1:  216
# - No.of passengers in Pclass-2:  184
# - No.of passengers in Pclass-2:  491

# %% [markdown]
# ## % of passengers in each class along with no.of passengers:

# %%
plot=sns.countplot(x='Pclass',data=titanic_df)
total=len(titanic_df)
for patch in plot.patches:
    count=patch.get_height()
    x=patch.get_x()+0.1
    y=count/2
    per=count/total*100
    percentage="{:.2f}%".format(per)
    annotation=f"{count}({percentage})"
    plot.annotate(annotation,(x,y))

# %% [markdown]
# ### Conclusion:
# - No.of passengers in Pclass-1: 216 and % of passengers in Pclass-1 is :24.24%
# - No.of passengers in Pclass-2: 184 and % of passengers in Pclass-1 is :20.65%
# - No.of passengers in Pclass-2: 491 and % of passengers in Pclass-1 is :55.11%

# %% [markdown]
# - Therefore,from this we can say that the passengers travelled more in Pclass-3 i.ee., >50%
# - Less people travelled in Pclass-2 (20.65%) only

# %% [markdown]
# # SURVIVAL RATE OF PASSENGERS TRAVELLED IN EACH CLASS:

# %% [markdown]
# ### Using seaborn:

# %%
plot1=sns.countplot(x='Pclass',hue='Survived',data=titanic_df)

# %%
for patch in plot1.patches:
    print(patch)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.4, height=80, angle=0)
# Rectangle(xy=(0.6, 0), width=0.4, height=97, angle=0)
# Rectangle(xy=(1.6, 0), width=0.4, height=372, angle=0)
# Rectangle(xy=(-2.77556e-17, 0), width=0.4, height=136, angle=0)
# Rectangle(xy=(1, 0), width=0.4, height=87, angle=0)
# Rectangle(xy=(2, 0), width=0.4, height=119, angle=0)

# %%
plot1=sns.countplot(x='Pclass',hue='Survived',data=titanic_df)
for patch in plot1.patches:
    count=patch.get_height()
    x=patch.get_x()+0.2
    y=count/2
    plot1.annotate(count,(x,y))

# %% [markdown]
# ### Using pandas:

# %%
titanic_df.g89iroupby('Pclass').Survived.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1248\3309289512.py in <module>
# ----> 1 titanic_df.g89iroupby('Pclass').Survived.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'g89iroupby'

# %% [markdown]
# ### Conclusion:
# - No.of passengers survived in Pclass-1: 136
# - No.of passengers survived in Pclass-2: 87
# - No.of passengers survived in Pclass-3: 119

# %%
plot1=sns.countplot(x='Pclass',hue='Survived',data=titanic_df)
i=1
j=1
for patch in plot1.patches[0:3]:
    total=len(titanic_df[titanic_df['Pclass']==i])
    count=patch.get_height()
    x=patch.get_x()-0.1
    y=count/2
    per=count/total*100
    percentage='{:.2f}%'.format(per)
    value=f"{count}({percentage})"
    plot1.annotate(value,(x,y))
    i=i+1
for patch in plot1.patches[3:]:
        total=len(titanic_df[titanic_df['Pclass']==j])
        count=patch.get_height()
        x=patch.get_x()
        y=count/2
        per=count/total*100
        percentage='{:.2f}%'.format(per)
        value=f"{count}({percentage})"
        plot1.annotate(value,(x,y))
        j=j+1

# %% [markdown]
# ## Conclusion:
# -  survival rate of passengers in Pclass-1: 62.96%
# -  survival rate of passengers in Pclass-2: 47.28%
# -  survival rate of passengers in Pclass-3: 24.24%
#
# - Therefore, passengers in Pclass-1  have highest survival rate (62.96%)
# - passenegers in Pclass-3 have least survival rate (24.24%)

# %% [markdown]
# # Most frequent boarding point

# %% [markdown]
# ## Using seaborn:

# %%
plot2=sns.countplot(x='Embarked',data=titanic_df)

# %%
for patch in plot2.patches:
    print(patch)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=644, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=168, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=77, angle=0)

# %%
plot2=sns.countplot(x='Embarked',data=titanic_df)
for patch in plot2.patches:
    count=patch.get_height()
    x=patch.get_x()+0.4
    y=count+1
    plot2.annotate(count,(x,y))

# %% [markdown]
# ## Using pandas:

# %%
titanic_df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
len(titanic_df[titanic_df['Embarked']=='S'])
# Out:
# 644

# %% [markdown]
# ### conclusion:
# - Most of passengers boarded at 'S' point (644 passengers)

# %% [markdown]
# # Survival rate based on gender

# %%
plot3=sns.countplot(x='Sex',hue='Survived',data=titanic_df)

# %%
for patch in plot3.patches:
    print(patch)
# Out:
# Rectangle(xy=(-0.4, 0), width=0.4, height=468, angle=0)
# Rectangle(xy=(0.6, 0), width=0.4, height=81, angle=0)
# Rectangle(xy=(-2.77556e-17, 0), width=0.4, height=109, angle=0)
# Rectangle(xy=(1, 0), width=0.4, height=233, angle=0)

# %%
plot3=sns.countplot(x='Sex',hue='Survived',data=titanic_df)
for patch in plot3.patches[0:3:2]:
    total=len(titanic_df[titanic_df['Sex']=='male'])
    count=patch.get_height()
    x=patch.get_x()
    y=count/2
    per=count/total*100
    percentage="{:.2f}%".format(per)
    value=f"{count}({percentage})"
    plot3.annotate(value,(x,y))
for patch in plot3.patches[1::2]:
        total=len(titanic_df[titanic_df['Sex']=='female'])
        count=patch.get_height()
        x=patch.get_x()
        y=count/2
        per=count/total*100
        percentage="{:.2f}%".format(per)
        value=f"{count}({percentage})"
        plot3.annotate(value,(x,y))

# %% [markdown]
# ## Conclusion:
# - survival rate of Male :18.89%(109)
# - survival rate of female:74.20%(233)
#
# - Therefore, the survival rate of male is least

# %% [markdown]
# # Distribution analysis based on fare:

# %%
sns.displot(x='Fare',data=titanic_df)

# %%
sns.displot(x='Fare',data=titanic_df,bins=10)

# %% [markdown]
# - from above graph we can say 500 is outlier and can eliminate outliers

# %% [markdown]
# ## dropping outliers:

# %%
df1=titanic_df.drop(titanic_df[titanic_df['Fare']>500].index,axis=0)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.displot(x='Fare',data=df1,bins=10)

# %% [markdown]
# # how many passengers paid top frequent fare?

# %%
titanic_df['Fare'].mode()
# Out:
# 0    8.05
# Name: Fare, dtype: float64

# %%
titanic_df['Fare'].mode().loc[0]
# Out:
# 8.05

# %% [markdown]
# ## list of passengers paid top frequent fare

# %%
titanic_df[titanic_df['Fare']==titanic_df['Fare'].mode().loc[0]]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 4              5         0       3                 Allen, Mr. William Henry
# 12            13         0       3           Saundercock, Mr. William Henry
# 37            38         0       3                 Cann, Mr. Ernest Charles
# 45            46         0       3                 Rogers, Mr. William John
# 77            78         0       3                 Moutal, Mr. Rahamin Haim
# 87            88         0       3            Slocovski, Mr. Selman Francis
# 89            90         0       3                   Celotti, Mr. Francesco
# 90            91         0       3                     Christmann, Mr. Emil
# 95            96         0       3              Shorney, Mr. Charles Joseph
# 112          113         0       3                   Barton, Mr. David John
# 121          122         0       3               Moore, Mr. Leonard Charles
# ...

# %%
len(titanic_df[titanic_df['Fare']==titanic_df['Fare'].mode().loc[0]])
# Out:
# 43

# %% [markdown]
# ### Conclusion:
# - Total 43 passengers paid top frequent fare i.e.., $8.05

# %% [markdown]
# ## How many people travelling for free:

# %%
titanic_df[titanic_df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
len(titanic_df[titanic_df['Fare']==0])
# Out:
# 15

# %% [markdown]
# ### Conclusion:
# - Total 15 passengers are travelling for free

# %% [markdown]
# ## Distribution analysis on age:

# %%
sns.displot(x='Age',data=titanic_df,bins=10)

# %% [markdown]
# ### The most old age people trvalled in which class

# %%
sns.boxplot(x='Pclass',y='Age',data=titanic_df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
titanic_df[titanic_df['Age']>70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
titanic_df[titanic_df['Age']>70]['Pclass'].mode()
# Out:
# 0    1
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Conclusion:
# - most of old age people travelled in Pclass-1

# %% [markdown]
# ## How many passengers have travelled alone

# %%
sibsp_zero=titanic_df[titanic_df['SibSp']==0]

# %%
sibsp_zero
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Using seaborn:

# %%
plot4=sns.countplot(x='Parch',data=sibsp_zero)

# %%
plot4=sns.countplot(x='Parch',data=sibsp_zero)
for patch in plot4.patches:
    if patch.get_height()>2:
        count=patch.get_height()
        x=patch.get_x()+0.4
        y=patch.get_height()/2
        plot4.annotate(count,(x,y))

# %% [markdown]
# ## Using pandas:

# %%
alone_df=sibsp_zero[sibsp_zero['Parch']==0]

# %%
alone_df
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 2              3         1       3        Heikkinen, Miss. Laina  female
# 4              5         0       3      Allen, Mr. William Henry    male
# 5              6         0       3              Moran, Mr. James    male
# 6              7         0       1       McCarthy, Mr. Timothy J    male
# 11            12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 884          885         0       3        Sutehall, Mr. Henry Jr    male
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
# 889          890         1       1         Behr, Mr. Karl Howell    male
# 890          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
len(alone_df)
# Out:
# 537

# %% [markdown]
# ### Conclusion:
# - Total 537 passengers travelled alone

# %% [markdown]
# ## Correlating Columns:

# %%
titanic_df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
help(sns.heatmap)
# Out:
# Help on function heatmap in module seaborn.matrix:
#
# heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)
#     Plot rectangular data as a color-encoded matrix.
#
#     This is an Axes-level function and will draw the heatmap into the
#     currently-active Axes if none is provided to the ``ax`` argument.  Part of
#     this Axes space will be taken and used to plot a colormap, unless ``cbar``
#     is False or a separate Axes is provided to ``cbar_ax``.
#
#     Parameters
#     ----------
#     data : rectangular dataset
#         2D dataset that can be coerced into an ndarray. If a Pandas DataFrame
#         is provided, the index/column information will be used to label the
#         columns and rows.
#     vmin, vmax : floats, optional
# ...

# %%
sns.heatmap(titanic_df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion:
# - 1. With increase in Pclass ----> Survival rate got decreased(-0.005) Therefore, safest Class is Pclass-1
# - 2.With increase in Pclass--->Fare got decreased(-0.55) Therefore, Pclass-1 is richest class
# - 3.with increase in age of passengers ---->Survival rate got decreased. Therefore old age passengers survival rate is less
# - 4.with increase in age of passengers---->Pclass increase.Therefore,old age people prefered Pclass-1 the most

# %% [markdown]
# ## Handling Missing values or Pre-Processing:

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### No.of null values in each column:

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Age : 177 missing values
# - cabin :687 missing values
# - embarked:2 missing values

# %% [markdown]
# ## filling missing values :

# %%
df1=titanic_df.fillna({'Age':titanic_df['Age'].mean(),'Embarked':titanic_df['Embarked'].mode().loc[0]})

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### droping cabin column
# - as >50% data of cabin column is missing

# %%
df1.drop('Cabin',axis=1,inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# - ML can't take object values so pre-processing it with numerical values

# %%
titanic_df.describe(include=object)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# - Name,sex,Ticket,Cabin,Embarked are object columns
# - drop Name,Ticket,Cabin
# - refill sex and embarked with numerical stuff

# %%
df2=df1.drop(['Name','Ticket'],axis=1)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
encoded_sex=pd.get_dummies(df2['Sex'])

# %%
encoded_sex
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
df3=pd.concat([df2,encoded_sex],axis=1)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked  female  male
# ...

# %%
encoded_embarked=pd.get_dummies(df3['Embarked'])

# %%
encoded_embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
df5=pd.concat([df3,encoded_embarked],axis=1)

# %%
df5
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked  female  male  C  Q  S
# ...

# %%
df5.drop(['Sex','Embarked'],axis=1,inplace=True)

# %%
df5
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  female  \
# 0              1         0       3  22.000000      1      0   7.2500       0
# 1              2         1       1  38.000000      1      0  71.2833       1
# 2              3         1       3  26.000000      0      0   7.9250       1
# 3              4         1       1  35.000000      1      0  53.1000       1
# 4              5         0       3  35.000000      0      0   8.0500       0
# ..           ...       ...     ...        ...    ...    ...      ...     ...
# 886          887         0       2  27.000000      0      0  13.0000       0
# 887          888         1       1  19.000000      0      0  30.0000       1
# 888          889         0       3  29.699118      1      2  23.4500       1
# 889          890         1       1  26.000000      0      0  30.0000       0
# 890          891         0       3  32.000000      0      0   7.7500       0
#
#      male  C  Q  S
# 0       1  0  0  1
# ...

# %%
pre_processed_titanic_df=df5

# %%
pre_processed_titanic_df
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare  female  \
# 0              1         0       3  22.000000      1      0   7.2500       0
# 1              2         1       1  38.000000      1      0  71.2833       1
# 2              3         1       3  26.000000      0      0   7.9250       1
# 3              4         1       1  35.000000      1      0  53.1000       1
# 4              5         0       3  35.000000      0      0   8.0500       0
# ..           ...       ...     ...        ...    ...    ...      ...     ...
# 886          887         0       2  27.000000      0      0  13.0000       0
# 887          888         1       1  19.000000      0      0  30.0000       1
# 888          889         0       3  29.699118      1      2  23.4500       1
# 889          890         1       1  26.000000      0      0  30.0000       0
# 890          891         0       3  32.000000      0      0   7.7500       0
#
#      male  C  Q  S
# 0       1  0  0  1
# ...

# %% [markdown]
# ### Conclusion:
# - data got pre_processed and ready to train ML
